# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("Downloads/property.csv")

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
# 9     423423.0   345.0       23423            ,            5        5  4500

# %%
#to get the current shape of an array
data.shape
# Out:
# (10, 7)

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED NUM_BEDROOMS NUM_BATH SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y            3        1  1000
# 1  100002000.0   197.0   LEXINGTON            N            3      1.5    --
# 2  100003000.0     NaN   LEXINGTON            N          NaN        1   850
# 3  100004000.0   201.0    BERKELEY           12            1      NaN   700
# 4          NaN   203.0    BERKELEY            Y            3        2  1600
# 5  100006000.0   207.0    BERKELEY            Y          NaN        1   800
# 6  100007000.0     NaN  WASHINGTON          NaN            2   HURLEY   950
# 7  100008000.0   213.0     TREMONT            Y            1        1   NaN
# 8  100009000.0   215.0     TREMONT            Y           na        2  1800
# 9     423423.0   345.0       23423            ,            5        5  4500

# %%
# concise summary of the dataframe. 
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   PID           9 non-null      float64
#  1   ST_NUM        8 non-null      float64
#  2   ST_NAME       10 non-null     object
#  3   OWN_OCCUPIED  9 non-null      object
#  4   NUM_BEDROOMS  8 non-null      object
#  5   NUM_BATH      9 non-null      object
#  6   SQ_FT         9 non-null      object
# dtypes: float64(2), object(5)
# memory usage: 688.0+ bytes

# %%
#The describe() method is used for calculating some statistical data
data.describe()
# Out:
#                 PID      ST_NUM
# count  9.000000e+00    8.000000
# mean   8.894038e+07  210.625000
# std    3.319386e+07   65.246647
# min    4.234230e+05  104.000000
# 25%    1.000020e+08  200.000000
# 50%    1.000040e+08  205.000000
# 75%    1.000070e+08  213.500000
# max    1.000090e+08  345.000000

# %%
#checking the data type 
data.dtypes
# Out:
# PID             float64
# ST_NUM          float64
# ST_NAME          object
# OWN_OCCUPIED     object
# NUM_BEDROOMS     object
# NUM_BATH         object
# SQ_FT            object
# dtype: object

# %%
#check the null value
data.isnull()
# Out:
#      PID  ST_NUM  ST_NAME  OWN_OCCUPIED  NUM_BEDROOMS  NUM_BATH  SQ_FT
# 0  False   False    False         False         False     False  False
# 1  False   False    False         False         False     False  False
# 2  False    True    False         False          True     False  False
# 3  False   False    False         False         False      True  False
# 4   True   False    False         False         False     False  False
# 5  False   False    False         False          True     False  False
# 6  False    True    False          True         False     False  False
# 7  False   False    False         False         False     False   True
# 8  False   False    False         False         False     False  False
# 9  False   False    False         False         False     False  False

# %%
#checking the null values
data.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    2
# NUM_BATH        1
# SQ_FT           1
# dtype: int64

# %%
#check Indivisal coloumns For null values 
print(data['SQ_FT'].isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6    False
# 7     True
# 8    False
# 9    False
# Name: SQ_FT, dtype: bool

# %%
print(data['ST_NUM'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5    False
# 6     True
# 7    False
# 8    False
# 9    False
# Name: ST_NUM, dtype: bool

# %%
print(data['NUM_BATH'].isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5    False
# 6    False
# 7    False
# 8    False
# 9    False
# Name: NUM_BATH, dtype: bool

# %%
print(data['NUM_BEDROOMS'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8    False
# 9    False
# Name: NUM_BEDROOMS, dtype: bool

# %%
data['NUM_BEDROOMS'].isnull().sum()
# Out:
# 2

# %%
#configure missing values at read time
missing=["na","--"]

# %%
data=pd.read_csv("Downloads/property.csv", na_values=missing)

# %%
data.isnull().sum()
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    1
# NUM_BEDROOMS    3
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
print (data['NUM_BEDROOMS'].isnull())
# Out:
# 0    False
# 1    False
# 2     True
# 3    False
# 4    False
# 5     True
# 6    False
# 7    False
# 8     True
# 9    False
# Name: NUM_BEDROOMS, dtype: bool

# %%
data['NUM_BEDROOMS'].isnull().sum()
# Out:
# 3

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY           12           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0
# 9     423423.0   345.0       23423            ,           5.0        5  4500.0

# %%
#invalid data is also treated as missing values, so replace invalid data withNaN
List = ['Y','N',np.nan]

# %%
for row in data['OWN_OCCUPIED']:
    if row in List:
        print("Data is valid")
        else:
            print("data is invalid")
# Out:
#   File "<ipython-input-26-12436f57aa5a>", line 4
#     else:
#     ^
# SyntaxError: invalid syntax

# %%
List=['Y','N',np.nan]

# %%
cnt=0
for row in data['OWN_OCCUPIED']:
    if row in List:
        cnt+=1
        pass
    else:
        data.loc[cnt,'OWN_OCCUPIED']=np.nan
        cnt+=1

# %%
data
# Out:
#            PID  ST_NUM     ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0      PUTNAM            Y           3.0        1  1000.0
# 1  100002000.0   197.0   LEXINGTON            N           3.0      1.5     NaN
# 2  100003000.0     NaN   LEXINGTON            N           NaN        1   850.0
# 3  100004000.0   201.0    BERKELEY          NaN           1.0      NaN   700.0
# 4          NaN   203.0    BERKELEY            Y           3.0        2  1600.0
# 5  100006000.0   207.0    BERKELEY            Y           NaN        1   800.0
# 6  100007000.0     NaN  WASHINGTON          NaN           2.0   HURLEY   950.0
# 7  100008000.0   213.0     TREMONT            Y           1.0        1     NaN
# 8  100009000.0   215.0     TREMONT            Y           NaN        2  1800.0
# 9     423423.0   345.0       23423          NaN           5.0        5  4500.0

# %%
print(data.isnull().sum())
# Out:
# PID             1
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    3
# NUM_BEDROOMS    3
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
#Handeling missing values
#sometime you may need to replace in indivisal values 
data.loc[4,'PID']=100005000

# %%
print(data.isnull().sum())
# Out:
# PID             0
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    3
# NUM_BEDROOMS    3
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
#impute missing values using mean median mode
median = data['NUM_BEDROOMS'].median()
data['NUM_BEDROOMS'].fillna(median,inplace=True)

# %%
print(data.isnull().sum())
# Out:
# PID             0
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    3
# NUM_BEDROOMS    0
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
#impute missing values using Mean/ Median/ Mode
median = data['NUM_BEDROOMS'].median()
data['NUM_BEDROOMS'].fillna(median,inplace=True)

# %%
print (data.isnull().sum())
# Out:
# PID             0
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    3
# NUM_BEDROOMS    0
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
mode = data['NUM_BATH'].mode()
data['NUM_BATH'].fillna(mode,inplace=True)

# %%
print (data.isnull().sum())
# Out:
# PID             0
# ST_NUM          2
# ST_NAME         0
# OWN_OCCUPIED    3
# NUM_BEDROOMS    0
# NUM_BATH        1
# SQ_FT           2
# dtype: int64

# %%
#some time you are supposed to delete all rows with missing values 
data.dropna(inplace=True)
data.reset_index(drop=True, inplace=True)

# %%
data
# Out:
#            PID  ST_NUM   ST_NAME OWN_OCCUPIED  NUM_BEDROOMS NUM_BATH   SQ_FT
# 0  100001000.0   104.0    PUTNAM            Y           3.0        1  1000.0
# 1  100005000.0   203.0  BERKELEY            Y           3.0        2  1600.0
# 2  100006000.0   207.0  BERKELEY            Y           3.0        1   800.0
# 3  100009000.0   215.0   TREMONT            Y           3.0        2  1800.0

# %%
#Working with a real world data set missing value part2
df=pd.read_csv("Downloads/diabetes.csv")

# %%
df.shape
# Out:
# (768, 9)

# %%
df.head()
# Out:
#    times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  Hour_insulin  \
# 0           6            148            72                 35             0
# 1           1             85            66                 29             0
# 2           8            183            64                  0             0
# 3           1             89            66                 23            94
# 4           0            137            40                 35           168
#
#     BMI  D_pedigree  Age   Class
# 0  33.6       0.627    50      1
# 1  26.6       0.351    31      0
# 2  23.3       0.672    32      1
# 3  28.1       0.167    21      0
# 4  43.1       2.288    33      1

# %%
df.columns
# Out:
# Index(['times_preg', 'gluco_concent', 'Diastolic BP', 'Triceps_Thickness',
#        'Hour_insulin', 'BMI', 'D_pedigree', 'Age ', 'Class'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   times_preg         768 non-null    int64
#  1   gluco_concent      768 non-null    int64
#  2   Diastolic BP       768 non-null    int64
#  3   Triceps_Thickness  768 non-null    int64
#  4   Hour_insulin       768 non-null    int64
#  5   BMI                768 non-null    float64
#  6   D_pedigree         768 non-null    float64
#  7   Age                768 non-null    int64
#  8   Class              768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
df.describe()
# Out:
#        times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  \
# count  768.000000     768.000000    768.000000         768.000000
# mean     3.845052     120.894531     69.105469          20.536458
# std      3.369578      31.972618     19.355807          15.952218
# min      0.000000       0.000000      0.000000           0.000000
# 25%      1.000000      99.000000     62.000000           0.000000
# 50%      3.000000     117.000000     72.000000          23.000000
# 75%      6.000000     140.250000     80.000000          32.000000
# max     17.000000     199.000000    122.000000          99.000000
#
#        Hour_insulin         BMI  D_pedigree        Age        Class
# count    768.000000  768.000000  768.000000  768.000000  768.000000
# mean      79.799479   31.992578    0.471876   33.240885    0.348958
# std      115.244002    7.884160    0.331329   11.760232    0.476951
# min        0.000000    0.000000    0.078000   21.000000    0.000000
# ...

# %%
df.head(20)
# Out:
#     times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  Hour_insulin  \
# 0            6            148            72                 35             0
# 1            1             85            66                 29             0
# 2            8            183            64                  0             0
# 3            1             89            66                 23            94
# 4            0            137            40                 35           168
# 5            5            116            74                  0             0
# 6            3             78            50                 32            88
# 7           10            115             0                  0             0
# 8            2            197            70                 45           543
# 9            8            125            96                  0             0
# 10           4            110            92                  0             0
# ...

# %%
print((df[['gluco_concent','Diastolic BP','Triceps_Thickness','Hour_insulin','BMI']]==0).sum())
# Out:
# gluco_concent          5
# Diastolic BP          35
# Triceps_Thickness    227
# Hour_insulin         374
# BMI                   11
# dtype: int64

# %%
#replacing  0's with NaN

# %%
df[['gluco_concent','Diastolic BP','Triceps_Thickness','Hour_insulin','BMI']]=df[['gluco_concent','Diastolic BP','Triceps_Thickness','Hour_insulin', 'BMI']].replace(0,np.NaN)

# %%
df.isnull().sum()
# Out:
# times_preg             0
# gluco_concent          5
# Diastolic BP          35
# Triceps_Thickness    227
# Hour_insulin         374
# BMI                   11
# D_pedigree             0
# Age                    0
# Class                  0
# dtype: int64

# %%
df.head(20)
# Out:
#     times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  Hour_insulin  \
# 0            6          148.0          72.0               35.0           NaN
# 1            1           85.0          66.0               29.0           NaN
# 2            8          183.0          64.0                NaN           NaN
# 3            1           89.0          66.0               23.0          94.0
# 4            0          137.0          40.0               35.0         168.0
# 5            5          116.0          74.0                NaN           NaN
# 6            3           78.0          50.0               32.0          88.0
# 7           10          115.0           NaN                NaN           NaN
# 8            2          197.0          70.0               45.0         543.0
# 9            8          125.0          96.0                NaN           NaN
# 10           4          110.0          92.0                NaN           NaN
# ...

# %%
df2=df.copy()

# %%
df.head()
# Out:
#    times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  Hour_insulin  \
# 0           6          148.0          72.0               35.0           NaN
# 1           1           85.0          66.0               29.0           NaN
# 2           8          183.0          64.0                NaN           NaN
# 3           1           89.0          66.0               23.0          94.0
# 4           0          137.0          40.0               35.0         168.0
#
#     BMI  D_pedigree  Age   Class
# 0  33.6       0.627    50      1
# 1  26.6       0.351    31      0
# 2  23.3       0.672    32      1
# 3  28.1       0.167    21      0
# 4  43.1       2.288    33      1

# %%
#remove rows and coloumns with missinf data
df.dropna(inplace=True)

# %%
df.shape
# Out:
# (392, 9)

# %%
df2.shape
# Out:
# (768, 9)

# %%
#Replace with mean value
df2.fillna(df2.mean(), inplace=True)

# %%
df2.head(10)
# Out:
#    times_preg  gluco_concent  Diastolic BP  Triceps_Thickness  Hour_insulin  \
# 0           6          148.0     72.000000           35.00000    155.548223
# 1           1           85.0     66.000000           29.00000    155.548223
# 2           8          183.0     64.000000           29.15342    155.548223
# 3           1           89.0     66.000000           23.00000     94.000000
# 4           0          137.0     40.000000           35.00000    168.000000
# 5           5          116.0     74.000000           29.15342    155.548223
# 6           3           78.0     50.000000           32.00000     88.000000
# 7          10          115.0     72.405184           29.15342    155.548223
# 8           2          197.0     70.000000           45.00000    543.000000
# 9           8          125.0     96.000000           29.15342    155.548223
#
#          BMI  D_pedigree  Age   Class
# 0  33.600000       0.627    50      1
# 1  26.600000       0.351    31      0
# ...

# %%
df2.isnull().sum()
# Out:
# times_preg           0
# gluco_concent        0
# Diastolic BP         0
# Triceps_Thickness    0
# Hour_insulin         0
# BMI                  0
# D_pedigree           0
# Age                  0
# Class                0
# dtype: int64
